# %% [markdown]
# <a href="https://colab.research.google.com/github/priyansh21112002/CIA-Country-Description/blob/main/CIA_Country_Facts.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.cluster import KMeans

# %%
df=pd.read_csv("/content/CIA_Country_Facts.csv")
df.head()
# Out:
#           Country                               Region  ...  Industry  Service
# 0     Afghanistan        ASIA (EX. NEAR EAST)           ...     0.240    0.380
# 1         Albania  EASTERN EUROPE                       ...     0.188    0.579
# 2         Algeria  NORTHERN AFRICA                      ...     0.600    0.298
# 3  American Samoa  OCEANIA                              ...       NaN      NaN
# 4         Andorra  WESTERN EUROPE                       ...       NaN      NaN
#
# [5 rows x 20 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 227 entries, 0 to 226
# Data columns (total 20 columns):
#  #   Column                              Non-Null Count  Dtype
# ---  ------                              --------------  -----
#  0   Country                             227 non-null    object
#  1   Region                              227 non-null    object
#  2   Population                          227 non-null    int64
#  3   Area (sq. mi.)                      227 non-null    int64
#  4   Pop. Density (per sq. mi.)          227 non-null    float64
#  5   Coastline (coast/area ratio)        227 non-null    float64
#  6   Net migration                       224 non-null    float64
#  7   Infant mortality (per 1000 births)  224 non-null    float64
#  8   GDP ($ per capita)                  226 non-null    float64
#  9   Literacy (%)                        209 non-null    float64
#  10  Phones (per 1000)                   223 non-null    float64
# ...

# %%
df.describe()
# Out:
#          Population  Area (sq. mi.)  ...    Industry     Service
# count  2.270000e+02    2.270000e+02  ...  211.000000  212.000000
# mean   2.874028e+07    5.982270e+05  ...    0.282711    0.565283
# std    1.178913e+08    1.790282e+06  ...    0.138272    0.165841
# min    7.026000e+03    2.000000e+00  ...    0.020000    0.062000
# 25%    4.376240e+05    4.647500e+03  ...    0.193000    0.429250
# 50%    4.786994e+06    8.660000e+04  ...    0.272000    0.571000
# 75%    1.749777e+07    4.418110e+05  ...    0.341000    0.678500
# max    1.313974e+09    1.707520e+07  ...    0.906000    0.954000
#
# [8 rows x 18 columns]

# %%
df.dtypes
# Out:
# Country                                object
# Region                                 object
# Population                              int64
# Area (sq. mi.)                          int64
# Pop. Density (per sq. mi.)            float64
# Coastline (coast/area ratio)          float64
# Net migration                         float64
# Infant mortality (per 1000 births)    float64
# GDP ($ per capita)                    float64
# Literacy (%)                          float64
# Phones (per 1000)                     float64
# Arable (%)                            float64
# Crops (%)                             float64
# Other (%)                             float64
# Climate                               float64
# Birthrate                             float64
# Deathrate                             float64
# Agriculture                           float64
# Industry                              float64
# Service                               float64
# dtype: object

# %%
df.shape
# Out:
# (227, 20)

# %%
df.isnull().sum()
# Out:
# Country                                0
# Region                                 0
# Population                             0
# Area (sq. mi.)                         0
# Pop. Density (per sq. mi.)             0
# Coastline (coast/area ratio)           0
# Net migration                          3
# Infant mortality (per 1000 births)     3
# GDP ($ per capita)                     1
# Literacy (%)                          18
# Phones (per 1000)                      4
# Arable (%)                             2
# Crops (%)                              2
# Other (%)                              2
# Climate                               22
# Birthrate                              3
# Deathrate                              4
# Agriculture                           15
# Industry                              16
# Service                               15
# dtype: int64

# %%
df[df['Literacy (%)'].isnull()]
# Out:
#                   Country  ... Service
# 25   Bosnia & Herzegovina  ...   0.550
# 66          Faroe Islands  ...   0.620
# 74             Gaza Strip  ...   0.687
# 78              Gibraltar  ...     NaN
# 80              Greenland  ...     NaN
# 85               Guernsey  ...   0.870
# 99            Isle of Man  ...   0.860
# 104                Jersey  ...   0.930
# 108              Kiribati  ...   0.668
# 123             Macedonia  ...   0.563
# 134               Mayotte  ...     NaN
# 144                 Nauru  ...     NaN
# 185              Slovakia  ...   0.672
# 187       Solomon Islands  ...   0.470
# 209                Tuvalu  ...   0.562
# 220        Virgin Islands  ...   0.800
# 222             West Bank  ...   0.630
# 223        Western Sahara  ...   0.400
#
# [18 rows x 20 columns]

# %%
df['Literacy (%)'] = df['Literacy (%)'].fillna(df.groupby('Region')['Literacy (%)'].transform('mean'))

# %%
df[df['Agriculture'].isna()]['Country']
# Out:
# 3            American Samoa
# 4                   Andorra
# 78                Gibraltar
# 80                Greenland
# 83                     Guam
# 134                 Mayotte
# 140              Montserrat
# 144                   Nauru
# 153      N. Mariana Islands
# 171            Saint Helena
# 174    St Pierre & Miquelon
# 177              San Marino
# 208       Turks & Caicos Is
# 221       Wallis and Futuna
# 223          Western Sahara
# Name: Country, dtype: object

# %%
df[df['Agriculture'].isnull()] = df[df['Agriculture'].isnull()].fillna(0)

# %%
df[df['Climate'].isnull()][['Country','Region']]
# Out:
#            Country                               Region
# 5           Angola  SUB-SAHARAN AFRICA
# 36          Canada  NORTHERN AMERICA
# 50         Croatia  EASTERN EUROPE
# 66   Faroe Islands  WESTERN EUROPE
# 101          Italy  WESTERN EUROPE
# 115        Lebanon  NEAR EAST
# 118          Libya  NORTHERN AFRICA
# 120      Lithuania  BALTICS
# 121     Luxembourg  WESTERN EUROPE
# 129          Malta  WESTERN EUROPE
# 137        Moldova                 C.W. OF IND. STATES
# 138         Monaco  WESTERN EUROPE
# 141        Morocco  NORTHERN AFRICA
# 145          Nepal        ASIA (EX. NEAR EAST)
# 169         Russia                 C.W. OF IND. STATES
# 181         Serbia  EASTERN EUROPE
# 186       Slovenia  EASTERN EUROPE
# 200       Tanzania  SUB-SAHARAN AFRICA

# %%
df['Climate'] = df['Climate'].fillna(df.groupby('Region')['Climate'].transform('mean'))

# %%
df.isnull().sum()
# Out:
# Country                               0
# Region                                0
# Population                            0
# Area (sq. mi.)                        0
# Pop. Density (per sq. mi.)            0
# Coastline (coast/area ratio)          0
# Net migration                         1
# Infant mortality (per 1000 births)    1
# GDP ($ per capita)                    0
# Literacy (%)                          0
# Phones (per 1000)                     2
# Arable (%)                            1
# Crops (%)                             1
# Other (%)                             1
# Climate                               0
# Birthrate                             1
# Deathrate                             2
# Agriculture                           0
# Industry                              1
# Service                               1
# dtype: int64

# %%
df=df.dropna()

# %%
sns.histplot(data=df[df['Population']<500000000],x='Population')

# %%
plt.figure(figsize=(10,6),dpi=200)
sns.barplot(data=df,y='GDP ($ per capita)',x='Region',estimator=np.mean)
plt.xticks(rotation=90);

# %%
plt.figure(figsize=(10,6),dpi=200)
sns.scatterplot(data=df,x='GDP ($ per capita)',y='Phones (per 1000)',hue='Region')
plt.legend(loc=(1.05,0.5))

# %%
plt.figure(figsize=(10,6),dpi=200)
sns.scatterplot(data=df,x='GDP ($ per capita)',y='Literacy (%)',hue='Region')

# %%
sns.heatmap(df.corr())

# %%
X = df.drop("Country",axis=1)

# %%
X = pd.get_dummies(X)
X.head()
# Out:
#    Population  ...  Region_WESTERN EUROPE
# 0    31056997  ...                                           0
# 1     3581655  ...                                           0
# 2    32930091  ...                                           0
# 3       57794  ...                                           0
# 4       71201  ...                                           1
#
# [5 rows x 29 columns]

# %%
from sklearn.preprocessing import StandardScaler
scaler = StandardScaler()
scaled_X = scaler.fit_transform(X)
scaled_X
# Out:
# array([[ 0.0133285 ,  0.01855412, -0.20308668, ..., -0.31544015,
#         -0.54772256, -0.36514837],
#        [-0.21730118, -0.32370888, -0.14378531, ..., -0.31544015,
#         -0.54772256, -0.36514837],
#        [ 0.02905136,  0.97784988, -0.22956327, ..., -0.31544015,
#         -0.54772256, -0.36514837],
#        ...,
#        [-0.06726127, -0.04756396, -0.20881553, ..., -0.31544015,
#         -0.54772256, -0.36514837],
#        [-0.15081724,  0.07669798, -0.22840201, ..., -0.31544015,
#          1.82574186, -0.36514837],
#        [-0.14464933, -0.12356132, -0.2160153 , ..., -0.31544015,
#          1.82574186, -0.36514837]])

# %%
ssd = []

for k in range(2,30):
    
    model = KMeans(n_clusters=k)
    
    
    model.fit(scaled_X)
    
    #Sum of squared distances of samples to their closest cluster center.
    ssd.append(model.inertia_)

# %%
plt.plot(range(2,30),ssd,'o--')
plt.xlabel("K Value")
plt.ylabel(" Sum of Squared Distances")
# Out:
# Text(0, 0.5, ' Sum of Squared Distances')

# %%
pd.Series(ssd).diff().plot(kind='bar')

# %%
model = KMeans(n_clusters=15)
model.fit(scaled_X)
# Out:
# KMeans(n_clusters=15)

# %%
model.labels_
# Out:
# array([ 2,  5,  6, 12,  3, 13,  1,  1,  1, 10,  1, 12,  3, 10,  1, 11,  4,
#         1, 10,  3,  1,  2,  7,  4,  1,  5, 13,  1,  1,  4,  5,  2,  4,  2,
#         4,  2,  7,  1,  3,  2,  2,  1,  0,  1,  2,  2, 13,  1,  2,  5,  1,
#         5,  3, 13,  1,  1,  1,  6,  1, 13, 13,  9,  2,  3, 12,  3,  3,  1,
#        12, 13,  2, 11, 10,  3,  2,  8,  3,  7,  1,  1, 12,  1,  2,  2,  1,
#         2,  1,  8,  5,  3,  0,  4,  4, 11,  3,  3, 11,  3,  1,  4,  3, 11,
#        10, 13, 12,  4,  4, 11, 10,  4,  9, 11, 13,  2,  6,  3,  9,  3,  8,
#         5,  2,  2,  4,  4,  2,  3, 12,  1,  2,  1,  2,  1, 14, 10,  4,  1,
#         6, 13, 13, 12,  4,  3,  1, 12, 12,  1,  2,  2, 12,  3, 11,  4, 12,
#         1, 12,  1,  1,  4,  5,  3,  1, 11,  1,  5, 10,  2,  1,  1,  1,  7,
#         1, 12,  3,  2, 11,  2,  1,  2,  8,  5,  5, 12,  2, 13,  3,  4,  2,
#         1, 13,  3,  3, 11,  4, 10,  2,  4,  2, 12,  1,  6, 11, 10,  1, 12,
# ...

# %%
X['K=15 Clusters'] = model.labels_

# %%
X.corr()['K=15 Clusters'].sort_values().plot(kind='bar',figsize=(15,6))

# %%
iso_codes=pd.read_csv("/content/country_iso_codes.csv")
iso_codes
# Out:
#                                              Country                                         ISO Code
# 0                                        Afghanistan                                              AFG
# 1    Akrotiri and Dhekelia – See United Kingdom, The  Akrotiri and Dhekelia – See United Kingdom, The
# 2                                      Åland Islands                                              ALA
# 3                                            Albania                                              ALB
# 4                                            Algeria                                              DZA
# ..                                               ...                                              ...
# 296                                 Congo, Dem. Rep.                                              COD
# 297                             Congo, Repub. of the                                              COG
# ...

# %%
iso_mapping = iso_codes.set_index('Country')['ISO Code'].to_dict()
iso_mapping
# Out:
# {'Afghanistan': 'AFG',
#  'Akrotiri and Dhekelia – See United Kingdom, The': 'Akrotiri and Dhekelia – See United Kingdom, The',
#  'Albania': 'ALB',
#  'Algeria': 'DZA',
#  'American Samoa': 'ASM',
#  'Andorra': 'AND',
#  'Angola': 'AGO',
#  'Anguilla': 'AIA',
#  'Antarctica\u200a[a]': 'ATA',
#  'Antigua and Barbuda': 'ATG',
#  'Argentina': 'ARG',
#  'Armenia': 'ARM',
#  'Aruba': 'ABW',
#  'Ashmore and Cartier Islands – See Australia.': 'Ashmore and Cartier Islands – See Australia.',
#  'Australia': 'AUS',
#  'Australia\u200a[b]': 'AUS',
#  'Austria': 'AUT',
#  'Azerbaijan': 'AZE',
#  'Bahamas (the)': 'BHS',
#  'Bahrain': 'BHR',
#  'Bangladesh': 'BGD',
#  'Barbados': 'BRB',
#  'Belarus': 'BLR',
#  'Belgium': 'BEL',
#  'Belize': 'BLZ',
#  'Benin': 'BEN',
#  'Bermuda': 'BMU',
#  'Bhutan': 'BTN',
#  'Bolivia': 'BOL',
#  'Bolivia (Plurinational State of)': 'BOL',
#  'Bonaire\xa0Sint Eustatius\xa0Saba': 'BES',
#  'Bosnia and Herzegovina': 'BIH',
#  'Botswana': 'BWA',
# ...

# %%
df['ISO Code'] = df['Country'].map(iso_mapping)
df[['Country','ISO Code']]
# Out:
#             Country ISO Code
# 0       Afghanistan      AFG
# 1           Albania      ALB
# 2           Algeria      DZA
# 3    American Samoa      ASM
# 4           Andorra      AND
# ..              ...      ...
# 222       West Bank      NaN
# 223  Western Sahara      NaN
# 224           Yemen      YEM
# 225          Zambia      ZMB
# 226        Zimbabwe      ZWE
#
# [221 rows x 2 columns]

# %%
df['Cluster'] = model.labels_

# %%
import plotly.express as px

fig = px.choropleth(df, locations="ISO Code",
                    color="Cluster", 
                    hover_name="Country", # column to add to hover information
                    )
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>
#             <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>
#                 <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-latest.min.js"></script>
#             <div id="e6e79c2b-2e2d-415e-9201-f5da63443fbd" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("e6e79c2b-2e2d-415e-9201-f5da63443fbd")) {
#                     Plotly.newPlot(
#                         'e6e79c2b-2e2d-415e-9201-f5da63443fbd',
# ...
